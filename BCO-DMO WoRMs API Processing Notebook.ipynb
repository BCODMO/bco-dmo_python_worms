# %%
import pandas as pd
import requests
from urllib.parse import quote_plus
import os

# %% [markdown]
# #### Reading in and Deduplicating the Primary File by Taxa (probably downloaded from Laminar)

# %%
# Specify the input and output files (include the entire path name)
original_file = input("Enter the original CSV file name (with extension). The file path is relative from where this program is run: ")

# Save the original file within a variable called df
original_df = pd.read_csv(original_file)
# Out:
# Enter the original CSV file name (with extension). The file path is relative from where this program is run: ../940324_v1_larval_sebastes_diet_and_morphometric_data1.csv

# %%
# Run this block if you want to view the read-in original file
original_df
# Out:
#      Cruise   ISO_DateTime_UTC  ISO_DateTime_PDT  Line    St        Lat
# 0   BBB2104  2021-04-07T17:52Z  2021-04-07T10:52  90.0  35.0  33.249950  \
# 1   BBB2104  2021-04-07T17:52Z  2021-04-07T10:52  90.0  35.0  33.249950
# 2   BBB2104  2021-04-07T16:15Z   2021-04-07T9:15  90.0  30.0  33.418633
# 3   BBB2104  2021-04-07T16:15Z   2021-04-07T9:15  90.0  30.0  33.418633
# 4   BBB2104   2101-04-06T21:20  2101-04-06T14:20  93.3  35.0  32.848000
# ..      ...                ...               ...   ...   ...        ...
# 75  BBB2104  2021-04-07T21:04Z  2021-04-07T14:04  90.0  37.0  33.183783
# 76   SW2104  2021-04-15T20:46Z  2021-04-15T13:46  85.0  42.9  33.850000
# 77   SW2104  2021-04-15T20:46Z  2021-04-15T13:46  85.0  42.9  33.850000
# 78   SW2104  2021-04-15T20:46Z  2021-04-15T13:46  85.0  42.9  33.850000
# 79   SW2104  2021-04-15T20:46Z  2021-04-15T13:46  85.0  42.9  33.850000
#
#           Long  Tow_Depth  Mesh_Size Larva_ID  ... rad40 rad41  rad42  rad43
# 0  -118.254150      29.65        505    RF002  ...   NaN   NaN    NaN    NaN  \
# 1  -118.254150      29.65        505    RF004  ...   NaN   NaN    NaN    NaN
# 2  -117.906200      28.91        505    RF011  ...   NaN   NaN    NaN    NaN
# 3  -117.906200      28.91        505    RF012  ...   NaN   NaN    NaN    NaN
# 4  -117.535500      29.74        505    RF020  ...   NaN   NaN    NaN    NaN
# ..         ...        ...        ...      ...  ...   ...   ...    ...    ...
# 75 -118.388867      30.13        505    RF206  ...   NaN   NaN    NaN    NaN
# 76 -119.370000      32.42        505    RF209  ...   NaN   NaN    NaN    NaN
# 77 -119.370000      32.42        505    RF211  ...   NaN   NaN    NaN    NaN
# 78 -119.370000      32.42        505    RF212  ...   NaN   NaN    NaN    NaN
# 79 -119.370000      32.42        505    RF213  ...   NaN   NaN    NaN    NaN
#
#     rad44  rad45  rad46  rad47  rad48  rad49
# 0     NaN    NaN    NaN    NaN    NaN    NaN
# 1     NaN    NaN    NaN    NaN    NaN    NaN
# 2     NaN    NaN    NaN    NaN    NaN    NaN
# 3     NaN    NaN    NaN    NaN    NaN    NaN
# 4     NaN    NaN    NaN    NaN    NaN    NaN
# ..    ...    ...    ...    ...    ...    ...
# 75    NaN    NaN    NaN    NaN    NaN    NaN
# 76    NaN    NaN    NaN    NaN    NaN    NaN
# 77    NaN    NaN    NaN    NaN    NaN    NaN
# 78    NaN    NaN    NaN    NaN    NaN    NaN
# 79    NaN    NaN    NaN    NaN    NaN    NaN
#
# [80 rows x 66 columns]

# %%
# Identify the column containing species names in the original file
while True:
        column_name = input("Enter the name of the column that contains the scientific names: ")
        if column_name in original_df.columns:
            break  # Exit the loop if the column name is valid
        else:
            print(f"Column '{column_name}' not found. Please try again. (make sure capitalization pattern is accurate.)")
# Out:
# Enter the name of the column that contains the scientific names: Species

# %%
# Read out a list of deduplicated taxa from df

def get_unique_values(original_df, column_name):
    """Get unique values from a specified DataFrame column."""
    return original_df[column_name].unique()

unique_values = get_unique_values(original_df, column_name)
print(f"Unique values in column '{column_name}':\n{unique_values}")
# Out:
# Unique values in column 'Species':
# ['Sebastes semicinctus' 'Sebastes macdonaldi' 'Sebastes jordani'
#  'Sebastes melanostomus' 'Sebastes simulator' 'Sebastes rufinanus'
#  'Sebastes hopkinsi' 'Sebastes mystinus/entomelas' 'Sebastes DNW'
#  'Sebastes ensifer' 'Sebastes rufus' 'Sebastes aurora' 'Sebastes miniatus'
#  'Sebastes wilsoni' 'Sebastes levis' 'Sebastes goodei'
#  'Sebastes paucispinis' 'Sebastes saxicola' 'Sebastes moseri'
#  'Sebastes diploproa']

# %% [markdown]
# #### Fetching data from the WoRMs API

# %%
# Step 5: Fetch data from the API

def fetch_api_data(unique_values):
    """Fetch data from the WoRMS API for a list of unique scientific names."""
    base_url = 'https://www.marinespecies.org/rest/AphiaRecordsByMatchNames?scientificnames%5B%5D='
    api_results = []

    for each in unique_values:
        try:
            url_sp = quote_plus(each)
            url = f'{base_url}{url_sp}&marine_only=true'
            print("Next api query to run:")
            print(url)

            response = requests.get(url)
            response.raise_for_status()  # Raise an error for bad responses
            data = response.json()

            for i in data:
                for y in i:
                    y['PI_entered_name'] = each  # Add the scientific name to the result
                    api_results.append(y)

        except requests.exceptions.HTTPError as e:
            print(f"HTTP error: {e}")
            api_results.append({'PI_entered_name': each, 'error_message': 'HTTP error'})
        except Exception as e:
            print(f"Error fetching data: {e}. Likely this means no close match was found.")
            api_results.append({'PI_entered_name': each, 'error_message': 'Error fetching data'})
    print("The program finished processing and printing all API results.")

    return api_results

api_results = fetch_api_data(unique_values)
# Out:
# Next api query to run:
# https://www.marinespecies.org/rest/AphiaRecordsByMatchNames?scientificnames%5B%5D=Sebastes+semicinctus&marine_only=true
# The program finished processing and printing all API results.
# Next api query to run:
# https://www.marinespecies.org/rest/AphiaRecordsByMatchNames?scientificnames%5B%5D=Sebastes+macdonaldi&marine_only=true
# The program finished processing and printing all API results.
# Next api query to run:
# https://www.marinespecies.org/rest/AphiaRecordsByMatchNames?scientificnames%5B%5D=Sebastes+jordani&marine_only=true
# The program finished processing and printing all API results.
# Next api query to run:
# https://www.marinespecies.org/rest/AphiaRecordsByMatchNames?scientificnames%5B%5D=Sebastes+melanostomus&marine_only=true
# The program finished processing and printing all API results.
# Next api query to run:
# https://www.marinespecies.org/rest/AphiaRecordsByMatchNames?scientificnames%5B%5D=Sebastes+simulator&marine_only=true
# The program finished processing and printing all API results.
# Next api query to run:
# https://www.marinespecies.org/rest/AphiaRecordsByMatchNames?scientificnames%5B%5D=Sebastes+rufinanus&marine_only=true
# The program finished processing and printing all API results.
# Next api query to run:
# https://www.marinespecies.org/rest/AphiaRecordsByMatchNames?scientificnames%5B%5D=Sebastes+hopkinsi&marine_only=true
# The program finished processing and printing all API results.
# Next api query to run:
# https://www.marinespecies.org/rest/AphiaRecordsByMatchNames?scientificnames%5B%5D=Sebastes+mystinus%2Fentomelas&marine_only=true
# The program finished processing and printing all API results.
# Next api query to run:
# https://www.marinespecies.org/rest/AphiaRecordsByMatchNames?scientificnames%5B%5D=Sebastes+DNW&marine_only=true
# The program finished processing and printing all API results.
# Next api query to run:
# https://www.marinespecies.org/rest/AphiaRecordsByMatchNames?scientificnames%5B%5D=Sebastes+ensifer&marine_only=true
# The program finished processing and printing all API results.
# Next api query to run:
# https://www.marinespecies.org/rest/AphiaRecordsByMatchNames?scientificnames%5B%5D=Sebastes+rufus&marine_only=true
# The program finished processing and printing all API results.
# Next api query to run:
# https://www.marinespecies.org/rest/AphiaRecordsByMatchNames?scientificnames%5B%5D=Sebastes+aurora&marine_only=true
# The program finished processing and printing all API results.
# Next api query to run:
# https://www.marinespecies.org/rest/AphiaRecordsByMatchNames?scientificnames%5B%5D=Sebastes+miniatus&marine_only=true
# The program finished processing and printing all API results.
# Next api query to run:
# https://www.marinespecies.org/rest/AphiaRecordsByMatchNames?scientificnames%5B%5D=Sebastes+wilsoni&marine_only=true
# The program finished processing and printing all API results.
# Next api query to run:
# https://www.marinespecies.org/rest/AphiaRecordsByMatchNames?scientificnames%5B%5D=Sebastes+levis&marine_only=true
# The program finished processing and printing all API results.
# Next api query to run:
# https://www.marinespecies.org/rest/AphiaRecordsByMatchNames?scientificnames%5B%5D=Sebastes+goodei&marine_only=true
# The program finished processing and printing all API results.
# Next api query to run:
# https://www.marinespecies.org/rest/AphiaRecordsByMatchNames?scientificnames%5B%5D=Sebastes+paucispinis&marine_only=true
# The program finished processing and printing all API results.
# Next api query to run:
# https://www.marinespecies.org/rest/AphiaRecordsByMatchNames?scientificnames%5B%5D=Sebastes+saxicola&marine_only=true
# The program finished processing and printing all API results.
# Next api query to run:
# https://www.marinespecies.org/rest/AphiaRecordsByMatchNames?scientificnames%5B%5D=Sebastes+moseri&marine_only=true
# The program finished processing and printing all API results.
# Next api query to run:
# https://www.marinespecies.org/rest/AphiaRecordsByMatchNames?scientificnames%5B%5D=Sebastes+diploproa&marine_only=true
# The program finished processing and printing all API results.

# %%
# Convert the API results into a dataframe
api_results_df = pd.DataFrame(api_results)

# Display the API results dataframe within the Jupyter Notebook
## This DF represents all of the WoRMS metadata from the deduplicated Taxa in the original file")
api_results_df
# Out:
#     AphiaID                                                url
# 0    274851  https://www.marinespecies.org/aphia.php?p=taxd...  \
# 1    274814  https://www.marinespecies.org/aphia.php?p=taxd...
# 2    274806  https://www.marinespecies.org/aphia.php?p=taxd...
# 3    274819  https://www.marinespecies.org/aphia.php?p=taxd...
# 4    274854  https://www.marinespecies.org/aphia.php?p=taxd...
# 5    274846  https://www.marinespecies.org/aphia.php?p=taxd...
# 6    274800  https://www.marinespecies.org/aphia.php?p=taxd...
# 7    126175  https://www.marinespecies.org/aphia.php?p=taxd...
# 8    126175  https://www.marinespecies.org/aphia.php?p=taxd...
# 9    274790  https://www.marinespecies.org/aphia.php?p=taxd...
# 10   274847  https://www.marinespecies.org/aphia.php?p=taxd...
# 11   274774  https://www.marinespecies.org/aphia.php?p=taxd...
# 12   274820  https://www.marinespecies.org/aphia.php?p=taxd...
# 13   274868  https://www.marinespecies.org/aphia.php?p=taxd...
# 14   274812  https://www.marinespecies.org/aphia.php?p=taxd...
# 15   274798  https://www.marinespecies.org/aphia.php?p=taxd...
# 16   274833  https://www.marinespecies.org/aphia.php?p=taxd...
# 17   274848  https://www.marinespecies.org/aphia.php?p=taxd...
# 18   274822  https://www.marinespecies.org/aphia.php?p=taxd...
# 19   274787  https://www.marinespecies.org/aphia.php?p=taxd...
#
#            scientificname                      authority    status
# 0    Sebastes semicinctus                (Gilbert, 1897)  accepted  \
# 1     Sebastes macdonaldi     (Eigenmann & Beeson, 1893)  accepted
# 2        Sebastes jordani                (Gilbert, 1896)  accepted
# 3   Sebastes melanostomus  (Eigenmann & Eigenmann, 1890)  accepted
# 4      Sebastes simulator                     Chen, 1971  accepted
# 5      Sebastes rufinanus              Lea & Fitch, 1972  accepted
# 6       Sebastes hopkinsi                 (Cramer, 1895)  accepted
# 7                Sebastes                   Cuvier, 1829  accepted
# 8                Sebastes                   Cuvier, 1829  accepted
# 9        Sebastes ensifer                     Chen, 1971  accepted
# 10         Sebastes rufus  (Eigenmann & Eigenmann, 1890)  accepted
# 11        Sebastes aurora                (Gilbert, 1890)  accepted
# 12      Sebastes miniatus       (Jordan & Gilbert, 1880)  accepted
# 13       Sebastes wilsoni                (Gilbert, 1915)  accepted
# 14         Sebastes levis  (Eigenmann & Eigenmann, 1889)  accepted
# 15        Sebastes goodei  (Eigenmann & Eigenmann, 1890)  accepted
# 16   Sebastes paucispinis                    Ayres, 1854  accepted
# 17      Sebastes saxicola                (Gilbert, 1890)  accepted
# 18        Sebastes moseri                   Eitner, 1999  accepted
# 19     Sebastes diploproa                (Gilbert, 1890)  accepted
#
#    unacceptreason  taxonRankID     rank  valid_AphiaID             valid_name
# 0            None          220  Species         274851   Sebastes semicinctus  \
# 1            None          220  Species         274814    Sebastes macdonaldi
# 2            None          220  Species         274806       Sebastes jordani
# 3            None          220  Species         274819  Sebastes melanostomus
# 4            None          220  Species         274854     Sebastes simulator
# 5            None          220  Species         274846     Sebastes rufinanus
# 6            None          220  Species         274800      Sebastes hopkinsi
# 7            None          180    Genus         126175               Sebastes
# 8            None          180    Genus         126175               Sebastes
# 9            None          220  Species         274790       Sebastes ensifer
# 10           None          220  Species         274847         Sebastes rufus
# 11           None          220  Species         274774        Sebastes aurora
# 12           None          220  Species         274820      Sebastes miniatus
# 13           None          220  Species         274868       Sebastes wilsoni
# 14           None          220  Species         274812         Sebastes levis
# 15           None          220  Species         274798        Sebastes goodei
# 16           None          220  Species         274833   Sebastes paucispinis
# 17           None          220  Species         274848      Sebastes saxicola
# 18           None          220  Species         274822        Sebastes moseri
# 19           None          220  Species         274787     Sebastes diploproa
#
#     ...                                           citation
# 0   ...  Froese, R. and D. Pauly. Editors. (2025). Fish...  \
# 1   ...  Froese, R. and D. Pauly. Editors. (2025). Fish...
# 2   ...  Froese, R. and D. Pauly. Editors. (2025). Fish...
# 3   ...  Froese, R. and D. Pauly. Editors. (2025). Fish...
# 4   ...  Froese, R. and D. Pauly. Editors. (2025). Fish...
# 5   ...  Froese, R. and D. Pauly. Editors. (2025). Fish...
# 6   ...  Froese, R. and D. Pauly. Editors. (2025). Fish...
# 7   ...  Froese, R. and D. Pauly. Editors. (2025). Fish...
# 8   ...  Froese, R. and D. Pauly. Editors. (2025). Fish...
# 9   ...  Froese, R. and D. Pauly. Editors. (2025). Fish...
# 10  ...  Froese, R. and D. Pauly. Editors. (2025). Fish...
# 11  ...  Froese, R. and D. Pauly. Editors. (2025). Fish...
# 12  ...  Froese, R. and D. Pauly. Editors. (2025). Fish...
# 13  ...  Froese, R. and D. Pauly. Editors. (2025). Fish...
# 14  ...  Froese, R. and D. Pauly. Editors. (2025). Fish...
# 15  ...  Froese, R. and D. Pauly. Editors. (2025). Fish...
# 16  ...  Froese, R. and D. Pauly. Editors. (2025). Fish...
# 17  ...  Froese, R. and D. Pauly. Editors. (2025). Fish...
# 18  ...  Froese, R. and D. Pauly. Editors. (2025). Fish...
# 19  ...  Froese, R. and D. Pauly. Editors. (2025). Fish...
#
#                                          lsid isMarine isBrackish
# 0   urn:lsid:marinespecies.org:taxname:274851        1          0  \
# 1   urn:lsid:marinespecies.org:taxname:274814        1          0
# 2   urn:lsid:marinespecies.org:taxname:274806        1          0
# 3   urn:lsid:marinespecies.org:taxname:274819        1          0
# 4   urn:lsid:marinespecies.org:taxname:274854        1          0
# 5   urn:lsid:marinespecies.org:taxname:274846        1          0
# 6   urn:lsid:marinespecies.org:taxname:274800        1          0
# 7   urn:lsid:marinespecies.org:taxname:126175        1          1
# 8   urn:lsid:marinespecies.org:taxname:126175        1          1
# 9   urn:lsid:marinespecies.org:taxname:274790        1          0
# 10  urn:lsid:marinespecies.org:taxname:274847        1          0
# 11  urn:lsid:marinespecies.org:taxname:274774        1          0
# 12  urn:lsid:marinespecies.org:taxname:274820        1          0
# 13  urn:lsid:marinespecies.org:taxname:274868        1          0
# 14  urn:lsid:marinespecies.org:taxname:274812        1          0
# 15  urn:lsid:marinespecies.org:taxname:274798        1          1
# 16  urn:lsid:marinespecies.org:taxname:274833        1          0
# 17  urn:lsid:marinespecies.org:taxname:274848        1          0
# 18  urn:lsid:marinespecies.org:taxname:274822        1          0
# 19  urn:lsid:marinespecies.org:taxname:274787        1          0
#
#    isFreshwater isTerrestrial isExtinct match_type                  modified
# 0             0             0      None      exact  2008-01-15T17:27:08.177Z  \
# 1             0             0      None      exact  2008-01-15T17:27:08.177Z
# 2             0             0      None      exact  2008-01-15T17:27:08.177Z
# 3             0             0      None      exact  2008-01-15T17:27:08.177Z
# 4             0             0      None      exact  2008-01-15T17:27:08.177Z
# 5             0             0      None      exact  2008-01-15T17:27:08.177Z
# 6             0             0      None      exact  2008-01-15T17:27:08.177Z
# 7             0             0      None      exact  2014-11-21T13:09:37.943Z
# 8             0             0      None      exact  2014-11-21T13:09:37.943Z
# 9             0             0      None      exact  2008-01-15T17:27:08.177Z
# 10            0             0      None      exact  2008-01-15T17:27:08.177Z
# 11            0             0      None      exact  2008-01-15T17:27:08.177Z
# 12            0             0      None      exact  2008-01-15T17:27:08.177Z
# 13            0             0      None      exact  2008-01-15T17:27:08.177Z
# 14            0             0      None      exact  2008-01-15T17:27:08.177Z
# 15            0             0      None      exact  2008-01-15T17:27:08.177Z
# 16            0             0      None      exact  2008-01-15T17:27:08.177Z
# 17            0             0      None      exact  2008-01-15T17:27:08.177Z
# 18            0             0      None      exact  2008-01-15T17:27:08.177Z
# 19            0             0      None      exact  2008-01-15T17:27:08.177Z
#
#                 PI_entered_name
# 0          Sebastes semicinctus
# 1           Sebastes macdonaldi
# 2              Sebastes jordani
# 3         Sebastes melanostomus
# 4            Sebastes simulator
# 5            Sebastes rufinanus
# 6             Sebastes hopkinsi
# 7   Sebastes mystinus/entomelas
# 8                  Sebastes DNW
# 9              Sebastes ensifer
# 10               Sebastes rufus
# 11              Sebastes aurora
# 12            Sebastes miniatus
# 13             Sebastes wilsoni
# 14               Sebastes levis
# 15              Sebastes goodei
# 16         Sebastes paucispinis
# 17            Sebastes saxicola
# 18              Sebastes moseri
# 19           Sebastes diploproa
#
# [20 rows x 28 columns]

# %% [markdown]
# #### Saving the deduplicated and merged WoRMs results to a CSV

# %%
def save_results_to_csv(results, output_file):
    """Save the results to a CSV file."""
    resulting_df = pd.DataFrame(results)
    resulting_df.to_csv(output_file, index=False)  # Set index=False to avoid writing row numbers

# File name handling
deduplicated_worms_output_file = f'{original_file[:-4]}_deduplicated_worms_taxa_results.csv'
deduplicated_worms_output_file_name = str(deduplicated_worms_output_file)
save_results_to_csv(api_results, deduplicated_worms_output_file)

print(deduplicated_worms_output_file_name + " was saved in the same folder as the input file")
# Out:
# ../940324_v1_larval_sebastes_diet_and_morphometric_data1_deduplicated_worms_taxa_results.csv was saved in the same folder as the input file

# %% [markdown]
# #### Joining the API results to the original file

# %%
# Specify columns to keep from the API df after join is completed

merge_columns = [
        'PI_entered_name', 'AphiaID', 'scientificname',
        'status', 'rank', 'valid_name', 'lsid', 'match_type'
    ]

merged_df = original_df.merge(api_results_df[merge_columns],
                                  left_on=column_name,
                                  right_on='PI_entered_name',
                                  how='left')

## This df shows the merge_columns from the API results df joined to the original_df
merged_df
# Out:
#      Cruise   ISO_DateTime_UTC  ISO_DateTime_PDT  Line    St        Lat
# 0   BBB2104  2021-04-07T17:52Z  2021-04-07T10:52  90.0  35.0  33.249950  \
# 1   BBB2104  2021-04-07T17:52Z  2021-04-07T10:52  90.0  35.0  33.249950
# 2   BBB2104  2021-04-07T16:15Z   2021-04-07T9:15  90.0  30.0  33.418633
# 3   BBB2104  2021-04-07T16:15Z   2021-04-07T9:15  90.0  30.0  33.418633
# 4   BBB2104   2101-04-06T21:20  2101-04-06T14:20  93.3  35.0  32.848000
# ..      ...                ...               ...   ...   ...        ...
# 75  BBB2104  2021-04-07T21:04Z  2021-04-07T14:04  90.0  37.0  33.183783
# 76   SW2104  2021-04-15T20:46Z  2021-04-15T13:46  85.0  42.9  33.850000
# 77   SW2104  2021-04-15T20:46Z  2021-04-15T13:46  85.0  42.9  33.850000
# 78   SW2104  2021-04-15T20:46Z  2021-04-15T13:46  85.0  42.9  33.850000
# 79   SW2104  2021-04-15T20:46Z  2021-04-15T13:46  85.0  42.9  33.850000
#
#           Long  Tow_Depth  Mesh_Size Larva_ID  ... rad48 rad49
# 0  -118.254150      29.65        505    RF002  ...   NaN   NaN  \
# 1  -118.254150      29.65        505    RF004  ...   NaN   NaN
# 2  -117.906200      28.91        505    RF011  ...   NaN   NaN
# 3  -117.906200      28.91        505    RF012  ...   NaN   NaN
# 4  -117.535500      29.74        505    RF020  ...   NaN   NaN
# ..         ...        ...        ...      ...  ...   ...   ...
# 75 -118.388867      30.13        505    RF206  ...   NaN   NaN
# 76 -119.370000      32.42        505    RF209  ...   NaN   NaN
# 77 -119.370000      32.42        505    RF211  ...   NaN   NaN
# 78 -119.370000      32.42        505    RF212  ...   NaN   NaN
# 79 -119.370000      32.42        505    RF213  ...   NaN   NaN
#
#           PI_entered_name  AphiaID         scientificname    status     rank
# 0    Sebastes semicinctus   274851   Sebastes semicinctus  accepted  Species  \
# 1     Sebastes macdonaldi   274814    Sebastes macdonaldi  accepted  Species
# 2        Sebastes jordani   274806       Sebastes jordani  accepted  Species
# 3    Sebastes semicinctus   274851   Sebastes semicinctus  accepted  Species
# 4   Sebastes melanostomus   274819  Sebastes melanostomus  accepted  Species
# ..                    ...      ...                    ...       ...      ...
# 75           Sebastes DNW   126175               Sebastes  accepted    Genus
# 76   Sebastes semicinctus   274851   Sebastes semicinctus  accepted  Species
# 77   Sebastes semicinctus   274851   Sebastes semicinctus  accepted  Species
# 78       Sebastes jordani   274806       Sebastes jordani  accepted  Species
# 79   Sebastes semicinctus   274851   Sebastes semicinctus  accepted  Species
#
#                valid_name                                       lsid
# 0    Sebastes semicinctus  urn:lsid:marinespecies.org:taxname:274851  \
# 1     Sebastes macdonaldi  urn:lsid:marinespecies.org:taxname:274814
# 2        Sebastes jordani  urn:lsid:marinespecies.org:taxname:274806
# 3    Sebastes semicinctus  urn:lsid:marinespecies.org:taxname:274851
# 4   Sebastes melanostomus  urn:lsid:marinespecies.org:taxname:274819
# ..                    ...                                        ...
# 75               Sebastes  urn:lsid:marinespecies.org:taxname:126175
# 76   Sebastes semicinctus  urn:lsid:marinespecies.org:taxname:274851
# 77   Sebastes semicinctus  urn:lsid:marinespecies.org:taxname:274851
# 78       Sebastes jordani  urn:lsid:marinespecies.org:taxname:274806
# 79   Sebastes semicinctus  urn:lsid:marinespecies.org:taxname:274851
#
#     match_type
# 0        exact
# 1        exact
# 2        exact
# 3        exact
# 4        exact
# ..         ...
# 75       exact
# 76       exact
# 77       exact
# 78       exact
# 79       exact
#
# [80 rows x 74 columns]

# %% [markdown]
# #### Saving the merged API results with the original data file as a new CSV

# %%
# File name handling

def save_results_to_csv(results, output_file):
    """Save the results to a CSV file."""
    resulting_df = pd.DataFrame(results)
    resulting_df.to_csv(output_file, index=False)  # Set index=False to avoid writing row numbers

merged_worms_output_file = f'{original_file[:-4]}_merged_worms_bcodmo.csv'
merged_worms_output_file_name = str(merged_worms_output_file)
save_results_to_csv(merged_df, merged_worms_output_file)

print(merged_worms_output_file_name + " was saved in the same folder as the input file.")
# Out:
# ../940324_v1_larval_sebastes_diet_and_morphometric_data1_merged_worms_bcodmo.csv was saved in the same folder as the input file.
